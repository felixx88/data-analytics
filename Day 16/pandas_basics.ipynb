# %%
import pandas as pd

# %% [markdown]
# # Install This support library
# - openpyxl

# %%
import os

# %%
df = pd.read_excel("../Datasets/book_one.xlsx",header=None, names=['#','col1','col2','col3','col4'],
              index_col=0
              )  
# this output is knows as dataframe

# %%
df
# Out:
#    col1  col2  col3  col4
# #
# 1    23   345    98   -10
# 2    44   341    56    54
# 3    53   346    12   -45
# 4    34   234   122   -30
# 5    12   563    48     5

# %%
print(df)
# Out:
#    col1  col2  col3  col4
# #
# 1    23   345    98   -10
# 2    44   341    56    54
# 3    53   346    12   -45
# 4    34   234   122   -30
# 5    12   563    48     5

# %%
# how to seee particular column 
df['col1'] # series
# Out:
# #
# 1    23
# 2    44
# 3    53
# 4    34
# 5    12
# Name: col1, dtype: int64

# %%
df[['col1']]  # dataframe
# Out:
#    col1
# #
# 1    23
# 2    44
# 3    53
# 4    34
# 5    12

# %%
df[['col1', 'col2']]  # dataframe
# Out:
#    col1  col2
# #
# 1    23   345
# 2    44   341
# 3    53   346
# 4    34   234
# 5    12   563

# %%
df.iloc[0]  # row0
# Out:
# col1     23
# col2    345
# col3     98
# col4    -10
# Name: 1, dtype: int64

# %%
print(df['col1'].sum())
print(df['col2'].mean())
print(df['col3'].max())
print(df['col4'].min())
# Out:
# 166
# 365.8
# 122
# -45

# %%
df.col1.plot()
# Out:
# <Axes: xlabel='#'>

# %%
df.col1.plot(kind='bar')
# Out:
# <Axes: xlabel='#'>

# %%
df.col1.plot(kind='pie')
# Out:
# <Axes: ylabel='col1'>

# %%
df.col1.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot(kind='bar')
# Out:
# <Axes: xlabel='#'>

# %% [markdown]
# # Passing your manual  data dictonary to pandas

# %%
data = { "country": ["India", "Russia", "China", "Africa", "Brazil"],
        "population": [200.4, 143.5, 119.9, 135, 50.98],
          "gdp": [2.8, 1.3, 4.6, 0.56, 11.4],
          "area":[2848559, 488551, 12344, 833844, 584483],
        }
cdf = pd.DataFrame(data)

# %%
print(cdf['gdp'].mean())
# Out:
# 4.132

# %%
df.plot()
# Out:
# <Axes: xlabel='#'>

# %%
cdf.plot(kind='bar',x='country', y='population', figsize=(6, 4))
# Out:
# <Axes: xlabel='country'>

# %%
cdf.plot(kind='bar',x='country', y='population', logy=True)
# Out:
# <Axes: xlabel='country'>

# %%
cdf.plot(kind='bar',x='country', y='population', logy=True,color='yellow', alpha=0.5, hatch='//', edgecolor='green')
# Out:
# <Axes: xlabel='country'>

# %%
cdf.columns.tolist()
# Out:
# ['country', 'population', 'gdp', 'area']
